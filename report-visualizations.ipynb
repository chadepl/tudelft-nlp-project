# %% [markdown]
# # Report Visualizations

# %% [markdown]
# ## Load libraries

# %%
import csv
import nltk
import numpy as np
import altair as alt
import pandas as pd
import itertools 
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-af3abb26d944> in <module>()
#       2 import nltk
#       3 import numpy as np
# ----> 4 import altair as alt
#       5 import pandas as pd
#       6 import itertools
#
# ModuleNotFoundError: No module named 'altair'

# %% [markdown]
# ## Load datafiles

# %%
features = pd.read_csv('feature_set_small.csv')
features = features.drop('Unnamed: 0', axis=1)
labels = pd.read_csv('labels_set_small.csv')
labels = labels.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ## Visualizations

# %%
clickbait_labels = labelsDF[labelsDF.truthClass == clickbait]
#instancesDF.iloc[[1,4,6], :]
# Out:
#                       id    truthClass  \
# 0     608310377143799810  no-clickbait
# 1     609297109095972864  no-clickbait
# 2     609504474621612032     clickbait
# 3     609748367049105409  no-clickbait
# 4     608688782821453825     clickbait
# 5     609551038983475201     clickbait
# 6     609447408955719681  no-clickbait
# 7     609027430624288769  no-clickbait
# 8     608229011572068352  no-clickbait
# 9     609046214554755073  no-clickbait
# 10    609738211183751168  no-clickbait
# 11    609762671554990080  no-clickbait
# 12    608980783924178945  no-clickbait
# 13    609998126737395712  no-clickbait
# 14    608926452596273152     clickbait
# 15    609300383358418945  no-clickbait
# 16    608875876474851328  no-clickbait
# 17    610173844561788928  no-clickbait
# 18    609095030926635011  no-clickbait
# 19    608576531456249856  no-clickbait
# 20    609631563597389824     clickbait
# 21    609372816568360960     clickbait
# 22    610103181578764291  no-clickbait
# ...
